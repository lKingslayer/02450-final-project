# %%
from prody import *
import os
import sys
from tqdm import tqdm
import numpy as np

# %%
pocket_list = os.listdir('../kinase_prot/pockets/')
# Out:
# ['1skj_complex2.pdb', '2xj0_complex2.pdb', '6gn1_complex2.pdb', '4m7x_complex2.pdb', '3uzp_complex2.pdb', '3upz_complex2.pdb', '4fxp_complex2.pdb', '6ebw_complex2.pdb', '5w5j_complex2.pdb', '4rx7_complex2.pdb', '2c5n_complex2.pdb', '3kid_complex2.pdb', '1e9h_complex2.pdb', '5kqd_complex2.pdb', '2xyn_complex2.pdb', '6omu_complex2.pdb', '4yfi_complex2.pdb', '6fil_complex2.pdb', '4alu_complex2.pdb', '2ym7_complex2.pdb', '5i5z_complex2.pdb', '6c9p_complex2.pdb', '4dtk_complex2.pdb', '5toz_complex2.pdb', '1mrs_complex2.pdb', '5vil_complex2.pdb', '5orv_complex2.pdb', '4c4g_complex2.pdb', '3w1f_complex2.pdb', '3kc3_complex2.pdb', '4btm_complex2.pdb', '4z3v_complex2.pdb', '1om1_complex2.pdb', '2iw6_complex2.pdb', '4twc_complex2.pdb', '1g5s_complex2.pdb', '4tw9_complex2.pdb', '4mcv_complex2.pdb', '4ivb_complex2.pdb', '5iui_complex2.pdb', '3unj_complex2.pdb', '3qtq_complex2.pdb', '4uns_complex2.pdb', '5tq7_complex2.pdb', '5izf_complex2.pdb', '4wbo_complex2.pdb', '1pme_complex2.pdb', '3s0o_comp
# ...

# %%
ligand_fingerprints = []

for pocket in pocket_list:
    structure = parsePDB(f'../kinase_prot/pockets/{pocket}')
    protein = structure.select('protein')
    ligand = structure.select('not protein and not water')

    

    writePDB()
    break
# Out:
# 1skj_complex2.pdb
# ['ILE' 'ILE' 'ILE' 'ILE' 'ILE' 'ILE' 'ILE' 'ILE' 'ILE' 'THR' 'THR' 'THR'
#  'THR' 'THR' 'THR' 'THR' 'THR' 'THR' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG'
#  'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG'
#  'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG'
#  'ARG' 'ARG' 'ARG' 'ARG' 'SER' 'SER' 'SER' 'SER' 'SER' 'SER' 'SER' 'SER'
#  'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'ARG' 'ARG'
#  'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG' 'ARG'
#  'ARG' 'ARG' 'ARG' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU'
#  'GLU' 'SER' 'SER' 'SER' 'SER' 'SER' 'SER' 'SER' 'SER' 'GLU' 'GLU' 'GLU'
#  'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'GLU' 'THR' 'THR' 'THR' 'THR' 'THR'
#  'THR' 'THR' 'THR' 'THR' 'THR' 'THR' 'THR' 'THR' 'THR' 'THR' 'THR' 'THR'
#  'THR' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS' 'LYS'
#  'LYS' 'LYS' 'ALA' 'ALA' 'ALA' 'ALA' 'ALA' 'ALA' 'TYR' 'TYR' 'TYR' 'TYR'
# ...
